# %%
import sys
currentDir=%pwd
sys.path.append(currentDir)
import gipsy

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import gipsy
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as ticker

# %%
x = 12
y = 10


pH=7.4
#Insert uniprot Taxonomy ID
taxonomyID=83333
taxonomy_name="Escherichia coli \(strain K12"

csv_folder="Raw"
cut_folder="Cuts"
dbfile="Ecoli_Hres_db.csv"

# %%
df=pd.read_csv(dbfile)
df_ribosomal=df[df["prot_acc"].str.contains("ribosomal protein",case=False)].reset_index()
df_ribosomal_coord=df_ribosomal.loc[:,'A1':]
df_ribosomal_coord.sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-c84aa7ee4ced> in <module>()
#       1 df=pd.read_csv(dbfile)
#       2 df_ribosomal=df[df["prot_acc"].str.contains("ribosomal protein",case=False)].reset_index()
# ----> 3 df_ribosomal=df_ribosomal[df_ribosomal["prot_acc"].str.contains("ribosomal protein",case=False)].reset_index()
#       4 df_ribosomal_coord=df_ribosomal.loc[:,'A1':]
#       5 df_ribosomal_coord.sum()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    2956                 # to ndarray and maybe infer different dtype
#    2957                 level_values = _maybe_casted_values(lev, lab)
# -> 2958                 new_obj.insert(0, name, level_values)
#    2959
#    2960         new_obj.index = new_index
#
# ...

# %%
df_ribosomal
# Out:
#    level_0  index    prot_acc  \
# 0       54     59  ARLY_ECOBW
# 1      258    293  GARL_ECOBW
# 2      484    556  NARL_ECOLI
# 3      652    748  RL15_ECOBW
# 4      653    775  RLMB_ECOLI
# 5      654    776  RLUA_ECOLI
# 6      655    777  RLUC_ECOLI
# 7      656    778  RLUD_ECOLI
# 8      720    868  SRLD_ECOLI
#
#                                            prot_desc  prot_mass         pI  \
# 0  Argininosuccinate lyase OS=Escherichia coli (s...      50686   4.990576
# 1  5-keto-4-deoxy-D-glucarate aldolase OS=Escheri...      27424   5.448311
# 2  Nitrate-nitrite response regulator protein Nar...      23912   5.524600
# 3  50S ribosomal protein L15 OS=Escherichia coli ...      14971  10.949873
# 4  23S rRNA (guanosine-2~-O-)-methyltransferase R...      26768   5.906045
# 5  Ribosomal large subunit pseudouridine synthase...      24959   7.438936
# 6  Ribosomal large subunit pseudouridine synthase...      36118   9.150518
# ...

# %%
letterindex=gipsy.IndexMaker(x,'l')                                                              
numbercols=np.arange(1,y+1)                                                                
sns.set(style="white")                                                                     


fig,ax = plt.subplots()
rsdata=df_ribosomal_coord.sum().values.reshape((x,y)).T
df_rs=pd.DataFrame(rsdata,columns=letterindex,index=numbercols)
    
sns_plot=sns.heatmap(df_rs,cmap="Blues",annot=True,cbar=True)
sns_plot.xaxis.tick_top()

plt.show()
plt.close()
